# %%
import pandas as pd 


sub = pd.read_csv("/kaggle/input/llm-agentic-legal-information-retrieval/test.csv")
sub["predicted_citations"] = sub["query"]
sub.loc[:, ["query_id", "query"]].to_csv("submission.csv", index=False)
